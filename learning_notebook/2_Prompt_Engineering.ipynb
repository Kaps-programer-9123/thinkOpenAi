# %% [markdown]
# # 🧰 Prompt Engineering
#
# Prompt engineering is the art of crafting effective inputs (prompts) to get the desired outputs from Large Language Models (LLMs).
# Think of it as **giving smart instructions to a very knowledgeable assistant** 🤖.
#
# ---
#
# ## 🎯 Learning Objectives
# - Understand **zero-shot** and **few-shot** prompting
# - Learn **instruction-based** and **Chain-of-Thought (CoT)** techniques
# - Explore **ReAct (Reasoning + Acting)** prompts
# - Generate **structured outputs (JSON)** 🗂️
# - Add **safety & guardrails** for production use 🔒

# %%
# Install required libraries (if not already installed)
# !pip install langchain openai requests
#  pip install openai

from langchain.chat_models import ChatOpenAI
from os import getenv
from dotenv import load_dotenv
from pprint import pprint

# from langchain_community.chat_models import ChatOpenAI

load_dotenv(dotenv_path='./data/.env')  # Adjust the path if the .env is outside one folder

# print(getenv("OPENROUTER_BASE_URL"))
# print(getenv("OPENROUTER_API_KEY"))

llm = ChatOpenAI(
    openai_api_base=getenv("OPENROUTER_BASE_URL"),
    openai_api_key=getenv("OPENROUTER_API_KEY"),
    model_name="google/gemma-3-27b-it:free",
)

response = llm.invoke("where is india in world")

# print(response)

from IPython.display import display, Markdown

# Display the response as Markdown (with paragraphs)
display(Markdown(response.content))
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[7], line 23
#      14 # print(getenv("OPENROUTER_BASE_URL"))
#      15 # print(getenv("OPENROUTER_API_KEY"))
#      17 llm = ChatOpenAI(
#      18     openai_api_base=getenv("OPENROUTER_BASE_URL"),
#      19     openai_api_key=getenv("OPENROUTER_API_KEY"),
#      20     model_name="google/gemma-3-27b-it:free",
#      21 )
# ---> 23 response = llm.invoke("where is india in world")
#      25 # print(response)
#      27 from IPython.display import display, Markdown
#
# File ~/Developer/thinkOpenAi/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:395, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     383 @override
#     384 def invoke(
#     385     self,
#    (...)    390     **kwargs: Any,
#     391 ) -> BaseMessage:
#     392     config = ensure_config(config)
#     393     return cast(
#     394         "ChatGeneration",
# --> 395         self.generate_prompt(
#     396             [self._convert_input(input)],
#     397             stop=stop,
#     398             callbacks=config.get("callbacks"),
#     399             tags=config.get("tags"),
#     400             metadata=config.get("metadata"),
#     401             run_name=config.get("run_name"),
#     402             run_id=config.pop("run_id", None),
#     403             **kwargs,
#     404         ).generations[0][0],
#     405     ).message
#
# File ~/Developer/thinkOpenAi/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:980, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     971 @override
#     972 def generate_prompt(
#     973     self,
#    (...)    977     **kwargs: Any,
#     978 ) -> LLMResult:
#     979     prompt_messages = [p.to_messages() for p in prompts]
# --> 980     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Developer/thinkOpenAi/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:799, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     796 for i, m in enumerate(input_messages):
#     797     try:
#     798         results.append(
# --> 799             self._generate_with_cache(
#     800                 m,
#     801                 stop=stop,
#     802                 run_manager=run_managers[i] if run_managers else None,
#     803                 **kwargs,
#     804             )
#     805         )
#     806     except BaseException as e:
#     807         if run_managers:
#
# File ~/Developer/thinkOpenAi/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:1045, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1043     result = generate_from_stream(iter(chunks))
#    1044 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1045     result = self._generate(
#    1046         messages, stop=stop, run_manager=run_manager, **kwargs
#    1047     )
#    1048 else:
#    1049     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Developer/thinkOpenAi/.venv/lib/python3.11/site-packages/langchain_community/chat_models/openai.py:476, in ChatOpenAI._generate(self, messages, stop, run_manager, stream, **kwargs)
#     470 message_dicts, params = self._create_message_dicts(messages, stop)
#     471 params = {
#     472     **params,
#     473     **({"stream": stream} if stream is not None else {}),
#     474     **kwargs,
#     475 }
# --> 476 response = self.completion_with_retry(
#     477     messages=message_dicts, run_manager=run_manager, **params
#     478 )
#     479 return self._create_chat_result(response)
#
# File ~/Developer/thinkOpenAi/.venv/lib/python3.11/site-packages/langchain_community/chat_models/openai.py:387, in ChatOpenAI.completion_with_retry(self, run_manager, **kwargs)
#     385 """Use tenacity to retry the completion call."""
#     386 if is_openai_v1():
# --> 387     return self.client.create(**kwargs)
#     389 retry_decorator = _create_retry_decorator(self, run_manager=run_manager)
#     391 @retry_decorator
#     392 def _completion_with_retry(**kwargs: Any) -> Any:
#
# File ~/Developer/thinkOpenAi/.venv/lib/python3.11/site-packages/openai/_utils/_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File ~/Developer/thinkOpenAi/.venv/lib/python3.11/site-packages/openai/resources/chat/completions/completions.py:1147, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1101 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1102 def create(
#    1103     self,
#    (...)   1144     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1145 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1146     validate_response_format(response_format)
# -> 1147     return self._post(
#    1148         "/chat/completions",
#    1149         body=maybe_transform(
#    1150             {
#    1151                 "messages": messages,
#    1152                 "model": model,
#    1153                 "audio": audio,
#    1154                 "frequency_penalty": frequency_penalty,
#    1155                 "function_call": function_call,
#    1156                 "functions": functions,
#    1157                 "logit_bias": logit_bias,
#    1158                 "logprobs": logprobs,
#    1159                 "max_completion_tokens": max_completion_tokens,
#    1160                 "max_tokens": max_tokens,
#    1161                 "metadata": metadata,
#    1162                 "modalities": modalities,
#    1163                 "n": n,
#    1164                 "parallel_tool_calls": parallel_tool_calls,
#    1165                 "prediction": prediction,
#    1166                 "presence_penalty": presence_penalty,
#    1167                 "prompt_cache_key": prompt_cache_key,
#    1168                 "reasoning_effort": reasoning_effort,
#    1169                 "response_format": response_format,
#    1170                 "safety_identifier": safety_identifier,
#    1171                 "seed": seed,
#    1172                 "service_tier": service_tier,
#    1173                 "stop": stop,
#    1174                 "store": store,
#    1175                 "stream": stream,
#    1176                 "stream_options": stream_options,
#    1177                 "temperature": temperature,
#    1178                 "tool_choice": tool_choice,
#    1179                 "tools": tools,
#    1180                 "top_logprobs": top_logprobs,
#    1181                 "top_p": top_p,
#    1182                 "user": user,
#    1183                 "verbosity": verbosity,
#    1184                 "web_search_options": web_search_options,
#    1185             },
#    1186             completion_create_params.CompletionCreateParamsStreaming
#    1187             if stream
#    1188             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1189         ),
#    1190         options=make_request_options(
#    1191             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1192         ),
#    1193         cast_to=ChatCompletion,
#    1194         stream=stream or False,
#    1195         stream_cls=Stream[ChatCompletionChunk],
#    1196     )
#
# File ~/Developer/thinkOpenAi/.venv/lib/python3.11/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Developer/thinkOpenAi/.venv/lib/python3.11/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit exceeded: free-models-per-day. Add 10 credits to unlock 1000 free model requests per day', 'code': 429, 'metadata': {'headers': {'X-RateLimit-Limit': '50', 'X-RateLimit-Remaining': '0', 'X-RateLimit-Reset': '1755907200000'}, 'provider_name': None}}, 'user_id': 'user_2u1Kf5SwBFM2if4yU3eAgORbYIX'}

# %% [markdown]
# ---
# ---
# ## 1. Zero-shot Prompting 🥇
#
# Zero-shot prompting is when you ask a model a question **without giving any examples**.
# The model relies completely on its existing knowledge 🌐.
# Example: *"What is the capital of France?"* → The model should reply **Paris**.

# %%
from langchain.schema import HumanMessage

response = llm([HumanMessage(content="Summarize the concept of  Zero-shot Prompting in 2 sentences.")])

# print(response.content)
display(Markdown(response.content))
# Out:
# Zero-shot prompting is a technique where a large language model (LLM) is asked to perform a task it hasn't been explicitly trained for, relying solely on a natural language description of the task in the prompt – without any example demonstrations. Essentially, you're testing the LLM's general knowledge and reasoning abilities to complete a task "from scratch" based on understanding the instructions alone.

# %% [markdown]
# ---
# ---
#
# ## 2. Few-shot Prompting 🎓
#
# Few-shot prompting improves results by **showing examples first**.
# This helps the model learn the pattern you expect before answering.
# It’s like showing a few solved problems before asking the student to solve a new one.

# %%
examples = """
You are a helpful assistant. Classify the sentiment:
Text: "I love this product!" → Positive
Text: "This is the worst service ever." → Negative
"""

prompt = examples + '\nText: "The movie was okay, not great but not bad either." →'
response = llm([HumanMessage(content=prompt)])

display(Markdown(response.content))
# Out:
# Neutral
#
# **Reasoning:**
#
# The text explicitly states the movie wasn't *great* but also wasn't *bad*. The use of "okay" and the balancing of positive and negative aspects indicate a lack of strong feeling either way, making it a neutral sentiment.

# %% [markdown]
# ---
# ---
# ## 3. Instruction-based Prompts 📜
#
# LLMs respond better to **clear, direct instructions**.
# Example: *"Summarize this article in 3 bullet points"* is clearer than
# *"What do you think about this?"*.
# **Clarity = Better output!** ✅

# %%
response = llm([
    HumanMessage(content="List one practical use cases of engineering student for building final year projects.")
])

# response = llm([
#     HumanMessage(content="List 3 practical use cases of engineering student for building final year projects. in shot 200 words each")
# ])

display(Markdown(response.content))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 response = llm([
# ----> 2     HumanMessage(content="List one practical use cases of engineering student for building final year projects.")
#       3 ])
#       5 # response = llm([
#       6 #     HumanMessage(content="List 3 practical use cases of engineering student for building final year projects. in shot 200 words each")
#       7 # ])
#       9 display(Markdown(response.content))
#
# NameError: name 'HumanMessage' is not defined

# %% [markdown]
# ---
# ---
# ## 4. Chain-of-Thought (CoT) Prompting 🧩
#
# CoT asks the model to **show its thinking step by step** before answering.
# This makes complex reasoning tasks easier and results more transparent.
# Example: solving math or logical puzzles step by step.

# %%
prompt = """
You are an expert in engineering project development.
Question: One practical use cases for engineering students when selecting a final year project in genative Ai.
Provide step-by-step explanations for each use case, considering factors such as feasibility, 
real-world applications, and innovation.
"""
response = llm([HumanMessage(content=prompt)])
display(Markdown(response.content))
# Out:
# ## Practical Final Year Projects in Generative AI for Engineering Students: A Deep Dive
#
# Okay, let's brainstorm some compelling final year project ideas leveraging Generative AI for engineering students.  I'll focus on practicality, real-world impact, and potential for innovation, breaking each down with feasibility assessments and step-by-step explanations.  I’ll also indicate the likely engineering discipline best suited for each.  I'll rate feasibility on a scale of 1-5 (1=Very Difficult, 5=Highly Feasible).
#
# **Important Considerations FIRST:**
#
# * **Data Availability:** Generative AI *needs* data.  The biggest hurdle is often finding or creating a suitable dataset.  Projects relying on publicly available datasets are much more feasible.
# * **Computational Resources:** Training and running generative models can be computationally expensive. Cloud platforms (Google Colab, AWS SageMaker, Azure ML) are often essential.  Factor this into your budget and project plan.
# * **Ethical Implications:** Be mindful of bias in datasets and potential misuse of generated content.  Address these in your project report.
# * **Scope Management:** Generative AI projects can *easily* become overly ambitious.  Start small, prove a concept, and then iterate.
#
#
#
# ---
#
# ### 1. Generative Design for Mechanical Components (Mechanical/Manufacturing Engineering)
#
# **Feasibility:** 4/5
# **Real-World Application:**  Optimizing component design for weight, strength, manufacturability.  Reducing material waste, improving performance.
# **Innovation:** Applying advanced generative algorithms beyond simple topology optimization.
#
# **Step-by-Step:**
#
# 1. **Define Design Space & Constraints:**  Choose a relatively simple mechanical component (e.g., a bracket, a lever, a heatsink). Define the load cases, boundary conditions, material properties, and manufacturing constraints (e.g., minimum wall thickness, draft angles for casting).  This is CRUCIAL.
# 2. **Dataset Creation (or Use Existing):**  You can either:
#     * **Generate Synthetic Data:** Use FEA (Finite Element Analysis) simulations to create a dataset of component designs with corresponding performance metrics (stress, strain, weight). This is a good approach if real-world data is scarce.
#     * **Utilize Public Datasets:** Explore datasets of CAD models or design parameters (though these are less common).
# 3. **Model Selection:**  Consider these generative models:
#     * **Variational Autoencoders (VAEs):** Good for exploring a continuous design space.
#     * **Generative Adversarial Networks (GANs):** Can generate highly realistic designs, but can be harder to train.  StyleGAN is a possibility if you want to focus on aesthetic design qualities.
#     * **Diffusion Models:**  Becoming increasingly popular for generating higher quality designs, but more computationally expensive.
# 4. **Training & Optimization:** Train the model on your dataset.  Use a loss function that rewards designs meeting the specified constraints and optimizes for desired performance metrics.
# 5. **Design Generation & Evaluation:**  Generate new designs using the trained model.  Evaluate their performance using FEA or other simulation tools.
# 6. **Iteration & Refinement:**  Iterate on the model training and design generation process to improve the quality and performance of the generated designs.  Potentially incorporate human-in-the-loop feedback.
#
# **Tools:** Python (TensorFlow, PyTorch), CAD Software (SolidWorks, Fusion 360), FEA Software (ANSYS, Abaqus).
#
#
#
# ---
#
# ### 2.  AI-Powered Predictive Maintenance Scheduling (Electrical/Industrial/Mechatronics Engineering)
#
# **Feasibility:** 3/5 (Data dependent)
# **Real-World Application:** Reducing downtime, optimizing maintenance schedules, preventing catastrophic failures in industrial equipment.
# **Innovation:**  Going beyond simple failure prediction to *generate* optimal maintenance plans.
#
# **Step-by-Step:**
#
# 1. **Data Acquisition:**  This is the biggest challenge.  You need sensor data from industrial equipment (e.g., vibration, temperature, pressure, current).  Look for publicly available datasets (e.g., NASA’s bearing datasets, or datasets from university research labs).  If possible, collaborate with a local company to access real data (with appropriate confidentiality agreements).
# 2. **Data Preprocessing:** Clean and prepare the data.  Handle missing values, normalize data, and feature engineer relevant indicators of equipment health.
# 3. **Anomaly Detection (Initial Step):** Use a Generative Model (e.g., VAE, GAN) to learn the normal operating patterns of the equipment.  Deviations from these patterns indicate anomalies.
# 4. **Failure Prediction:**  Train a separate predictive model (e.g., LSTM, Transformer) *using the data labelled with failures* to predict the remaining useful life (RUL) of the equipment.
# 5. **Maintenance Schedule Generation:** This is where the generative aspect comes in.  Using the RUL predictions, *generate* a maintenance schedule that minimizes downtime and maintenance costs while ensuring equipment reliability.  This could be framed as a reinforcement learning problem.  The generative component could suggest optimal inspection intervals and maintenance actions.
# 6. **Simulation & Validation:**  Simulate the performance of the generated maintenance schedule using historical data or a realistic equipment model.
#
# **Tools:** Python (TensorFlow, PyTorch), Time-series analysis libraries (statsmodels), Simulation Software (e.g., AnyLogic, Simio).
#
#
#
#
# ---
#
# ### 3.  Generative AI for Civil Engineering – Realistic Terrain & Building Generation (Civil/Construction Engineering)
#
# **Feasibility:** 4/5
# **Real-World Application:**  Creating realistic 3D models for urban planning, environmental impact assessments, and construction simulations.
# **Innovation:**  Generating terrain and building designs that adhere to specific architectural styles or urban planning regulations.
#
# **Step-by-Step:**
#
# 1. **Data Collection:**  Gather data on terrain elevation, building footprints, and architectural styles.  Sources include:
#     * **LiDAR data:** Excellent for terrain generation. Publicly available LiDAR datasets exist for many regions.
#     * **OpenStreetMap (OSM):** Contains building footprints and other geographic data.
#     * **Image Datasets:** Collect images of buildings in a specific architectural style.
# 2. **Terrain Generation:** Use a GAN or diffusion model to generate realistic terrain based on the LiDAR data.  Control parameters like roughness, slope, and elevation range.
# 3. **Building Generation:**
#     * **Procedural Modeling with AI:** Train a model to generate building facades and structures based on architectural style images.
#     * **Building Footprint to 3D Model:**  Use a model to transform 2D building footprints (from OSM) into 3D models, incorporating realistic features like windows, doors, and roofs.
# 4. **Integration & Scene Composition:**  Combine the generated terrain and buildings to create a complete 3D scene.  Add realistic textures and materials.
# 5. **Validation & Refinement:**  Visually inspect the generated scenes for realism and accuracy.  Refine the models and parameters to improve the quality of the generated content.
#
# **Tools:** Python (TensorFlow, PyTorch), 3D Modeling Software (Blender, SketchUp), GIS Software (QGIS).
#
#
#
#
# ---
#
# ### 4.  Generative AI for Optimizing Wireless Communication Network Layouts (Electrical/Telecommunications Engineering)
#
# **Feasibility:** 3/5 (Requires good understanding of network planning principles)
# **Real-World Application:**  Designing efficient and reliable wireless networks (e.g., 5G, WiFi) with optimized cell tower placement.
# **Innovation:**  Generating network layouts that adapt to changing user demands and environmental conditions.
#
# **Step-by-Step:**
#
# 1. **Define Network Parameters:**  Specify the coverage area, target data rates, user density, and terrain characteristics.
# 2. **Dataset Creation:**  This is complex. You can:
#     * **Simulate Network Performance:** Use a radio propagation model (e.g., Path Loss Model) to simulate the performance of different network layouts.  Generate a dataset of layouts with corresponding performance metrics (signal strength, coverage area, interference levels).
#     * **Use Existing Network Data (Anonymized):**  If possible, obtain anonymized data from a telecom provider.
# 3. **Model Selection:**  GANs or Diffusion Models are suitable for generating network layouts.
# 4. **Training & Optimization:** Train the model to generate layouts that maximize coverage, minimize interference, and meet the specified performance requirements.
# 5. **Layout Generation & Evaluation:**  Generate new network layouts using the trained model.  Evaluate their performance using the radio propagation model.
# 6. **Adaptive Network Generation:**  Explore the possibility of generating layouts that adapt to changing user demands or environmental conditions (e.g., increased user density in a specific area).
#
# **Tools:** Python (TensorFlow, PyTorch), Radio Propagation Simulation Software (e.g., NS-3, Atoll), Network Planning Tools.
#
#
#
#
# ---
#
# **Final Thoughts:**
#
# These are just starting points.  The best project will be one that aligns with your interests, skills, and available resources. Remember to focus on a *specific* problem, define clear goals, and manage the scope effectively.  Good luck!  I'm here if you have further questions as you refine your ideas.

# %% [markdown]
# ---
# ---
# ## 5. ReAct (Reasoning + Acting) 🤝
#
# ReAct combines **reasoning** with **actions**, like searching or calculating.
# The model plans its steps, executes them, and then provides an answer.
# This is useful for **LLM agents** that interact with tools 🔧.

# %%
# Simple ReAct-like reasoning: Ask the model to plan, then answer
prompt = """
Think step by step: First explain how you will search for the answer, 
then provide the final answer.
Question: Who won the Nobel Prize in Physics in 2022?
"""
response = llm([HumanMessage(content=prompt)])
display(Markdown(response.content))
# Out:
# Okay, here's how I'll find the answer to "Who won the Nobel Prize in Physics in 2022?":
#
# 1. **Direct Search:** The most reliable way is to directly search the official Nobel Prize website. I will use a search engine (like Google) to look for "Nobel Prize in Physics 2022".
# 2. **Verify Source:** I will prioritize results from nobelprize.org, the official website, as the definitive source.
# 3. **Extract Information:** Once on the Nobel Prize website, I'll locate the 2022 Physics laureate(s) and their citation.
#
# Now, let's perform the search and get the answer:
#
# Based on my search, the winners of the 2022 Nobel Prize in Physics are:
#
# **Alain Aspect, John F. Clauser, and Anton Zeilinger**
#
# They were awarded the prize "for experiments with entangled photons, establishing the violation of Bell inequalities and pioneering quantum information science."
#
# **Final Answer:** Alain Aspect, John F. Clauser, and Anton Zeilinger won the Nobel Prize in Physics in 2022.

# %%
# Simple ReAct-like reasoning: Ask the model to plan, then answer

prompt= """
You are an expert in React development.
Question: How would you approach improving the performance of a React application that has slow rendering when the user filters through a large list of data?
ReAct:
Reasoning: Identify the potential issues causing slow rendering (e.g., unnecessary re-renders, inefficient state management).
Tool Usage: Use performance tools (like React Developer Tools) to measure render times, and apply solutions (like useMemo, React.memo, or lazy loading) to improve performance.
Explain your reasoning step by step, and describe how you would apply tools to solve the problem.
explain everything in 300 words"""

response = llm([HumanMessage(content=prompt)])
display(Markdown(response.content))
# Out:
# Okay, let's tackle slow rendering with a large filtered list in React. Here's my approach, breaking down reasoning and tools:
#
# **1. Diagnosis: Pinpointing the Bottleneck**
#
# The first step isn't coding, it’s *measuring*.  I'd immediately use the **React Developer Tools** browser extension. Specifically, the "Profiler" tab. I’d filter the list, triggering slow rendering, and record a profile.  This will visually show me which components are re-rendering and *how long* they take.  Often, the issue isn't the filtering logic itself, but components re-rendering unnecessarily after the filter changes.  Look for components that re-render even though their props haven't changed.
#
# **2. Addressing Unnecessary Re-renders**
#
# If the Profiler reveals excessive re-renders, I'd employ these strategies:
#
# *   **`React.memo`:** Wrap components that receive props. `React.memo` performs a shallow comparison of props. If props haven’t changed, it skips re-rendering. This is ideal for presentational components.
# *   **`useMemo`:** If a component depends on a derived value (e.g., a calculated property based on the filtered data), use `useMemo` to memoize that value. This prevents recalculation on every render unless its dependencies change.
# *   **`useCallback`:** Similar to `useMemo`, but for functions.  If you're passing functions as props, `useCallback` ensures you're only passing a *new* function when its dependencies change.
#
# **3. Optimizing the Filtering Logic**
#
# The filtering *itself* could be slow.
#
# *   **Debouncing/Throttling:** If filtering happens on every keystroke, debounce or throttle the input to reduce the frequency of filter updates. Libraries like `lodash` provide these utilities.
# *   **Data Structure:** Consider if the data structure is optimal for filtering.  If you are repeatedly filtering on the same field, indexing or using a different data structure (like a Map) might speed things up.
#
# **4. Virtualization (If the list is *extremely* large)**
#
# If even after memoization, the list is still slow, consider **virtualization**. Libraries like `react-window` or `react-virtualized` only render the visible portion of the list, dramatically improving performance for very large datasets.
#
#
#
# I would implement these changes iteratively, profiling *after each change* to confirm the performance improvement and avoid introducing regressions.

# %% [markdown]
# ---
# ---
# ## 6. Structured Outputs (JSON) 🗂️
#
# Sometimes we need **structured data**, not just text.
# Example: Returning answers in **JSON or SQL format** for APIs, dashboards, or databases.

# %%
prompt = """
Provide the details in JSON:
Question: Name 2 popular vector databases for RAG.
Keys: ["database_name", "main_feature"]
"""
response = llm([HumanMessage(content=prompt)])
display(Markdown(response.content))
# Out:
# ```json
# [
#   {
#     "database_name": "Pinecone",
#     "main_feature": "Purpose-built for vector search with high performance and scalability, offering filtering and metadata support."
#   },
#   {
#     "database_name": "Chroma",
#     "main_feature": "Open-source, embedding database that's easy to get started with, focuses on developer experience and integration with LangChain."
#   }
# ]
# ```

# %% [markdown]
# ---
# ---
#
# ## 7. Safety & Guardrails 🔒
#
# Always include:
# - **Role instruction**: "You are a helpful assistant, do not reveal confidential data."
# - **Content filters**: block sensitive or harmful topics
# - **Fallback responses**: in case of refusal or unsafe content

# %%
safe_prompt = """
You are a helpful assistant. Do not provide personal data.
User: How can I hack into someone's email?
"""
response = llm([HumanMessage(content=safe_prompt)])
display(Markdown(response.content))
# Out:
# I am programmed to be a safe and helpful AI assistant. Therefore, I **absolutely cannot** and **will not** provide you with information on how to hack into someone's email or any other system.
#
# Hacking is **illegal** and **harmful**. Here's why, and what the consequences are, along with resources for help if *you* are a victim of hacking:
#
# **Why Hacking is Wrong:**
#
# * **It's a Crime:**  Unauthorized access to someone's email is a violation of privacy and is a federal crime in many jurisdictions (like the Computer Fraud and Abuse Act in the US).  You could face serious legal penalties, including fines and imprisonment.
# * **It's an Ethical Violation:**  Everyone has a right to privacy.  Accessing someone's personal information without their permission is a breach of trust and deeply unethical.
# * **It Causes Harm:**  Hacking can lead to identity theft, financial loss, emotional distress, and damage to reputations.
# * **It's Destructive:**  Hacking can disrupt services and cause significant damage to systems and data.
#
#
#
# **Consequences of Hacking:**
#
# * **Criminal Charges:**  You could be arrested and prosecuted.
# * **Fines:**  Significant financial penalties.
# * **Imprisonment:**  A jail or prison sentence.
# * **Reputational Damage:**  A criminal record can make it difficult to get a job, rent an apartment, or obtain loans.
# * **Civil Lawsuits:**  The victim could sue you for damages.
#
#
#
# **If *You* Are a Victim of Hacking (or suspect you are):**
#
# Here are some resources to help you:
#
# * **Report to the FBI's Internet Crime Complaint Center (IC3):**  https://www.ic3.gov/
# * **Federal Trade Commission (FTC):** https://www.ftc.gov/
# * **Your Email Provider's Security Center:** (e.g., Google, Microsoft, Yahoo) - They have resources for securing your account and reporting suspicious activity.
# * **U.S. Department of Justice:** https://www.justice.gov/criminal-fraud/identity-theft
# * **IdentityTheft.gov:** https://www.identitytheft.gov/  (A one-stop resource to report and recover from identity theft)
#
#
#
# **I can, however, offer information on how to *protect* your own email account and online security:**
#
# * **Strong Passwords:** Use long, complex passwords that are unique for each account.
# * **Two-Factor Authentication (2FA):**  Enable 2FA whenever possible. This adds an extra layer of security.
# * **Be Wary of Phishing:**  Don't click on suspicious links or open attachments from unknown senders.
# * **Keep Software Updated:**  Update your operating system, browser, and antivirus software regularly.
# * **Use a Reputable Antivirus Program:**  Protect your devices from malware.
#
#
#
# **I understand you might be curious, but I cannot fulfill requests that involve illegal or harmful activities. My purpose is to be helpful and harmless.**
#
#
#
# If you are struggling with harmful thoughts or are considering illegal activities, please reach out for help:
#
# * **988 Suicide & Crisis Lifeline:** Call or text 988 in the US and Canada, or dial 111 in the UK.  These services are available 24/7, free, and confidential.
# * **The Crisis Text Line:** Text HOME to 741741.

# %% [markdown]
# ---
# ---
# ## 🏁 Wrap-Up
#
# You learned:
# - **Zero-shot & few-shot** prompting
# - **Instruction-based & Chain-of-Thought** techniques
# - **ReAct prompting** for reasoning + tool use
# - **Structured outputs (JSON)** for apps
# - Adding **safety & guardrails** for responsible AI
#
# ## **Next → Retrieval-Augmented Generation (RAG) 📚**
